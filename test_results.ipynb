# %%
import pickle as pkl

data = pkl.load(open('/home/ssnyde9/dev/lmao/tmp/ackley_run8.pkl', 'rb'))

# %%
data
# Out:
# {'time_log': [54.021414041519165,
#   58.78906607627869,
#   55.8919198513031,
#   57.146467447280884,
#   52.45565319061279],
#  'results_log': [{'x_log': array([[ 2.02926755e+00,  1.15395470e+01],
#           [-1.58353558e+01,  3.13854313e+01],
#           [ 1.88034213e+00, -2.89736080e+01],
#           [-2.31066971e+01,  1.85641384e+01],
#           [-1.75299606e+01, -1.68207378e+01],
#           [ 2.21620731e+01,  3.21928596e+01],
#           [ 3.06139126e+01,  1.68134518e+01],
#           [ 6.87410176e-01,  1.76809788e+00],
#           [-2.67351170e+01,  2.59635696e+01],
#           [-8.55002499e+00, -3.92012548e+00],
#           [-3.27680016e+01,  4.34466696e+00],
#           [ 9.25106466e-01,  1.69696844e+00],
#           [ 1.43692315e+00,  1.56622815e+00],
#           [-2.88933134e+00,  1.91503608e+00],
#           [-2.98371735e+01,  1.71194243e+00],
#           [ 5.16972399e+00,  2.22531891e+00],
#           [-2.03224346e-01,  9.65503693e-01],
# ...
