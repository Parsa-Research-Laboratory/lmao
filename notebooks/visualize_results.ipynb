# %%
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
import os
import pickle as pkl
import re

# %%
plt.rcParams.update({
    "text.usetex": True,
})

# %% [markdown]
# ### Load Results without Delay

# %%
data_dir: str = "/home/ssnyde9/dev/lmao/tmp"
file_prefix = "ackley_run"
file_suffix = ".pkl"

num_res: int = 20

# %%
results = []

for i in range(num_res):
    with open(f"{data_dir}/{file_prefix}{i+1}{file_suffix}", "rb") as f:
        results.append(pkl.load(f))

# %%
results[0].keys()
# Out:
# dict_keys(['time_log', 'results_log'])

# %%
run_times = np.zeros(num_res)

for i in range(num_res):
    run_times[i] = np.mean(results[i]["time_log"])

# %% [markdown]
# ### Load Results with Delay = 0.5

# %%
data_dir: str = "/home/ssnyde9/dev/lmao/tmp-d05"
file_prefix = "ackley_run"
file_suffix = ".pkl"

num_res: int = 20

results05 = []

for i in range(num_res):
    with open(f"{data_dir}/{file_prefix}{i+1}{file_suffix}", "rb") as f:
        results05.append(pkl.load(f))

run_times05 = np.zeros(num_res)

for i in range(num_res):
    run_times05[i] = np.mean(results05[i]["time_log"])

# %% [markdown]
# ### Load Results with Delay = 1.0

# %%
data_dir: str = "/home/ssnyde9/dev/lmao/tmp-d1"
file_prefix = "ackley_run"
file_suffix = ".pkl"

num_res: int = 20

results1 = []

for i in range(num_res):
    with open(f"{data_dir}/{file_prefix}{i+1}{file_suffix}", "rb") as f:
        results1.append(pkl.load(f))

run_times1 = np.zeros(num_res)

for i in range(num_res):
    run_times1[i] = np.mean(results1[i]["time_log"])

# %%
plt.plot(np.arange(1, num_res+1, 1), run_times, "-o", label="Delay = 0", c="#0000FF", alpha=0.5)
plt.plot(np.arange(1, num_res+1, 1), run_times05, "-o", label="Delay = 0.5", c="#FF0000", alpha=0.5)
plt.plot(np.arange(1, num_res+1, 1), run_times1, "--o", label="Delay = 1.0", c="#007700", alpha=0.5)
plt.ylabel("Run Time (s)")
plt.xlabel("Number of Processes")
plt.title("Run Time vs Number of Processes")
plt.ylim(25, 100)
plt.xlim(0, 10)
# plt.xticks([1, 4, 8, 12, 16, 20])
plt.legend()
